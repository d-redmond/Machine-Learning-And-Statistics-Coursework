# %% [markdown]
# # Topic 2: Models, Exercise 1

# %% [markdown]
# ###  Use numpy and matplotlib to plot the absolute value function.
#
# ### Research and explain why the absolute value function is not typically used in fitting straight lines to data.

# %%
# Importing numpy, matplotlib
import numpy as np
from matplotlib import pyplot as plt

# Plotting
x = np.arange(-3.14,3*3.14)
a = 2*x
b = x*3
y = np.abs(a*x+b)
plt.plot(x,y)
plt.xlabel('x values')
plt.ylabel('y values')
plt.title('absolute function')
plt.grid(True)
plt.show()

# %% [markdown]
# Absolute values are more prone to error during calculation in both mathematics and commputing. Using absolute values can result in discontinuous derivatives that cannot be treated analyticcally. The absolute value function also has no derivative at the origin. To avoid errors, we instead make use of the least squares method.

# %% [markdown]
# Resources:
#
# https://www.geeksforgeeks.org/numpy-absolute-python/
#
# https://www.sharpsightlabs.com/blog/numpy-absolute-value/
#
# https://sparkbyexamples.com/numpy/numpy-absolute-value/
#
# https://www.epythonguru.com/2019/11/how-to-plot-absolute-function.html
